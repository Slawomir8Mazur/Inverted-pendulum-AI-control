# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from database_def import Record
# %matplotlib inline

# %%
pendulum = Record()
pendulum.position_set(10)
print(pendulum)
# Out:
#    m_1  m_2  l  __x  _x  x  __fi  _fi        fi     g  t
# 0   20    2  1    0   0  0     0    0  0.174533  9.81  0
#
#    __x  _x   x  __fi  _fi  fi   t
# 1  NaN NaN NaN   NaN  NaN NaN NaN
#
#    __x  _x   x  __fi  _fi  fi   t
# 1  NaN NaN NaN   NaN  NaN NaN NaN

# %%
pendulum.move(((0,1),), dt_min=0.05)
pendulum.visualize(features=['move'], source=pendulum.last_movement, separately=False)

# %%
pendulum.save_to_database(database_name='parameters1')

# %%
pendulum_2 = Record()
pendulum_2.load_from_database(database_name='parameters1')
print(pendulum_2)
# Out:
#    index  m_1  m_2  l       __x        _x         x       __fi       _fi        fi     g    t
# 0      0   20    2  1 -2.183863 -0.163809  0.052184  10.039351  5.215305  2.096951  9.81  1.0
#
#     index       __x        _x         x      __fi       _fi        fi     t     fi[deg]
# 0       0  0.000000  0.000000  0.000000  0.000000  0.000000  0.174533  0.00   10.000000
# 1       1  0.000000  0.000000  0.000000  1.703489  0.085174  0.178792  0.05   10.244007
# 2       2  0.152277  0.007614  0.000381  1.894466  0.179898  0.187787  0.10   10.759376
# 3       3  0.168647  0.016046  0.001183  1.997060  0.279751  0.201774  0.15   11.560803
# 4       4  0.176442  0.024868  0.002426  2.138862  0.386694  0.221109  0.20   12.668599
# 5       5  0.186727  0.034205  0.004137  2.333627  0.503375  0.246278  0.25   14.110663
# 6       6  0.200131  0.044211  0.006347  2.585726  0.632661  0.277911  0.30   15.923104
# ...
