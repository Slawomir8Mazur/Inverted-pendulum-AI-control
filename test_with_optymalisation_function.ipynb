# %%
from database_def import Record

import os
import pandas as pd
from pendulum_nn_based import munge_records

# %%
db_folder_name = 'main_databases'
os.chdir(os.getcwd() + '\\' + db_folder_name)
names = os.listdir()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-c590174fdacd> in <module>
#       1 db_folder_name = 'main_databases'
# ----> 2 os.chdir(os.getcwd() + '\\' + db_folder_name)
#       3 names = os.listdir()
#
# FileNotFoundError: [WinError 2] Nie można odnaleźć określonego pliku: 'C:\\coding\\Inverted-pendulum-AI-control\\main_databases\\main_databases'

# %%
names = os.listdir()

# %%
#train_input, train_output = munge_records(names[::3000],
#                                          drop_some=(1, 700), order=5)
# Out:
# ['F_-1000_angle_1.db',
#  'F_-1000_angle_101.db',
#  'F_-1000_angle_106.db',
#  'F_-1000_angle_11.db',
#  'F_-1000_angle_111.db',
#  'F_-1000_angle_116.db',
#  'F_-1000_angle_121.db',
#  'F_-1000_angle_126.db',
#  'F_-1000_angle_131.db',
#  'F_-1000_angle_136.db',
#  'F_-1000_angle_141.db',
#  'F_-1000_angle_146.db',
#  'F_-1000_angle_151.db',
#  'F_-1000_angle_156.db',
#  'F_-1000_angle_16.db',
#  'F_-1000_angle_161.db',
#  'F_-1000_angle_166.db',
#  'F_-1000_angle_171.db',
#  'F_-1000_angle_176.db',
#  'F_-1000_angle_181.db',
#  'F_-1000_angle_186.db',
#  'F_-1000_angle_191.db',
#  'F_-1000_angle_196.db',
#  'F_-1000_angle_201.db',
#  'F_-1000_angle_206.db',
#  'F_-1000_angle_21.db',
#  'F_-1000_angle_211.db',
#  'F_-1000_angle_216.db',
#  'F_-1000_angle_221.db',
#  'F_-1000_angle_226.db',
#  'F_-1000_angle_231.db',
#  'F_-1000_angle_236.db',
#  'F_-1000_angle_241.db',
#  'F_-1000_angle_246.db',
#  'F_-1000_angle_251.db',
#  'F_-1000_angle_256.db',
#  'F_-1000_angle_26.db',
#  'F_-1000_angle_261.db',
#  'F_-1000_angle_266.db',
#  'F_-1000_angle_271.db',
#  'F_-1000_angle_276.db',
#  'F_-1000_angle_281.db',
#  'F_-1000_angle_286.db',
#  'F_-1000_angle_291.db',
#  'F_-1000_angle_296.db',
#  'F_-1000_angle_301.db',
#  'F_-1000_angle_306.db',
#  'F_-1000_angle_31.db',
#  'F_-1000_angle_311.db',
#  'F_-1000_angle_316.db',
#  'F_-1000_angle_321.db',
#  'F_-1000_angle_326.db',
#  'F_-1000_angle_331.db',
#  'F_-1000_angle_336.db',
#  'F_-1000_angle_341.db',
#  'F_-1000_angle_346.db',
#  'F_-1000_angle_351.db',
#  'F_-1000_angle_356.db',
#  'F_-1000_angle_36.db',
#  'F_-1000_angle_41.db',
#  'F_-1000_angle_46.db',
#  'F_-1000_angle_51.db',
#  'F_-1000_angle_56.db',
#  'F_-1000_angle_6.db',
#  'F_-1000_angle_61.db',
#  'F_-1000_angle_66.db',
#  'F_-1000_angle_71.db',
#  'F_-1000_angle_76.db',
#  'F_-1000_angle_81.db',
#  'F_-1000_angle_86.db',
#  'F_-1000_angle_91.db',
#  'F_-1000_angle_96.db',
#  'F_-100_angle_1.db',
#  'F_-100_angle_101.db',
#  'F_-100_angle_106.db',
#  'F_-100_angle_11.db',
#  'F_-100_angle_111.db',
#  'F_-100_angle_116.db',
#  'F_-100_angle_121.db',
#  'F_-100_angle_126.db',
#  'F_-100_angle_131.db',
#  'F_-100_angle_136.db',
#  'F_-100_angle_141.db',
#  'F_-100_angle_146.db',
#  'F_-100_angle_151.db',
#  'F_-100_angle_156.db',
#  'F_-100_angle_16.db',
#  'F_-100_angle_161.db',
#  'F_-100_angle_166.db',
#  'F_-100_angle_171.db',
#  'F_-100_angle_176.db',
#  'F_-100_angle_181.db',
#  'F_-100_angle_186.db',
#  'F_-100_angle_191.db',
#  'F_-100_angle_196.db',
#  'F_-100_angle_201.db',
#  'F_-100_angle_206.db',
#  'F_-100_angle_21.db',
#  'F_-100_angle_211.db',
#  'F_-100_angle_216.db',
#  'F_-100_angle_221.db',
#  'F_-100_angle_226.db',
#  'F_-100_angle_231.db',
#  'F_-100_angle_236.db',
#  'F_-100_angle_241.db',
#  'F_-100_angle_246.db',
#  'F_-100_angle_251.db',
#  'F_-100_angle_256.db',
#  'F_-100_angle_26.db',
#  'F_-100_angle_261.db',
#  'F_-100_angle_266.db',
#  'F_-100_angle_271.db',
#  'F_-100_angle_276.db',
#  'F_-100_angle_281.db',
#  'F_-100_angle_286.db',
#  'F_-100_angle_291.db',
#  'F_-100_angle_296.db',
#  'F_-100_angle_301.db',
#  'F_-100_angle_306.db',
#  'F_-100_angle_31.db',
#  'F_-100_angle_311.db',
#  'F_-100_angle_316.db',
#  'F_-100_angle_321.db',
#  'F_-100_angle_326.db',
#  'F_-100_angle_331.db',
#  'F_-100_angle_336.db',
#  'F_-100_angle_341.db',
#  'F_-100_angle_346.db',
#  'F_-100_angle_351.db',
#  'F_-100_angle_356.db',
#  'F_-100_angle_36.db',
#  'F_-100_angle_41.db',
#  'F_-100_angle_46.db',
#  'F_-100_angle_51.db',
#  'F_-100_angle_56.db',
#  'F_-100_angle_6.db',
#  'F_-100_angle_61.db',
#  'F_-100_angle_66.db',
#  'F_-100_angle_71.db',
#  'F_-100_angle_76.db',
#  'F_-100_angle_81.db',
#  'F_-100_angle_86.db',
#  'F_-100_angle_91.db',
#  'F_-100_angle_96.db',
#  'F_-1050_angle_1.db',
#  'F_-1050_angle_101.db',
#  'F_-1050_angle_106.db',
#  'F_-1050_angle_11.db',
#  'F_-1050_angle_111.db',
#  'F_-1050_angle_116.db',
#  'F_-1050_angle_121.db',
#  'F_-1050_angle_126.db',
#  'F_-1050_angle_131.db',
#  'F_-1050_angle_136.db',
#  'F_-1050_angle_141.db',
#  'F_-1050_angle_146.db',
#  'F_-1050_angle_151.db',
#  'F_-1050_angle_156.db',
#  'F_-1050_angle_16.db',
#  'F_-1050_angle_161.db',
#  'F_-1050_angle_166.db',
#  'F_-1050_angle_171.db',
#  'F_-1050_angle_176.db',
#  'F_-1050_angle_181.db',
#  'F_-1050_angle_186.db',
#  'F_-1050_angle_191.db',
#  'F_-1050_angle_196.db',
#  'F_-1050_angle_201.db',
#  'F_-1050_angle_206.db',
#  'F_-1050_angle_21.db',
#  'F_-1050_angle_211.db',
#  'F_-1050_angle_216.db',
#  'F_-1050_angle_221.db',
#  'F_-1050_angle_226.db',
#  'F_-1050_angle_231.db',
#  'F_-1050_angle_236.db',
#  'F_-1050_angle_241.db',
#  'F_-1050_angle_246.db',
#  'F_-1050_angle_251.db',
#  'F_-1050_angle_256.db',
#  'F_-1050_angle_26.db',
#  'F_-1050_angle_261.db',
#  'F_-1050_angle_266.db',
#  'F_-1050_angle_271.db',
#  'F_-1050_angle_276.db',
#  'F_-1050_angle_281.db',
#  'F_-1050_angle_286.db',
#  'F_-1050_angle_291.db',
#  'F_-1050_angle_296.db',
#  'F_-1050_angle_301.db',
#  'F_-1050_angle_306.db',
#  'F_-1050_angle_31.db',
#  'F_-1050_angle_311.db',
#  'F_-1050_angle_316.db',
#  'F_-1050_angle_321.db',
#  'F_-1050_angle_326.db',
#  'F_-1050_angle_331.db',
#  'F_-1050_angle_336.db',
#  'F_-1050_angle_341.db',
#  'F_-1050_angle_346.db',
#  'F_-1050_angle_351.db',
#  'F_-1050_angle_356.db',
#  'F_-1050_angle_36.db',
#  'F_-1050_angle_41.db',
#  'F_-1050_angle_46.db',
#  'F_-1050_angle_51.db',
#  'F_-1050_angle_56.db',
#  'F_-1050_angle_6.db',
#  'F_-1050_angle_61.db',
#  'F_-1050_angle_66.db',
#  'F_-1050_angle_71.db',
#  'F_-1050_angle_76.db',
#  'F_-1050_angle_81.db',
#  'F_-1050_angle_86.db',
#  'F_-1050_angle_91.db',
#  'F_-1050_angle_96.db',
#  'F_-1100_angle_1.db',
#  'F_-1100_angle_101.db',
#  'F_-1100_angle_106.db',
#  'F_-1100_angle_11.db',
#  'F_-1100_angle_111.db',
#  'F_-1100_angle_116.db',
#  'F_-1100_angle_121.db',
#  'F_-1100_angle_126.db',
#  'F_-1100_angle_131.db',
#  'F_-1100_angle_136.db',
#  'F_-1100_angle_141.db',
#  'F_-1100_angle_146.db',
#  'F_-1100_angle_151.db',
#  'F_-1100_angle_156.db',
#  'F_-1100_angle_16.db',
#  'F_-1100_angle_161.db',
#  'F_-1100_angle_166.db',
#  'F_-1100_angle_171.db',
#  'F_-1100_angle_176.db',
#  'F_-1100_angle_181.db',
#  'F_-1100_angle_186.db',
#  'F_-1100_angle_191.db',
#  'F_-1100_angle_196.db',
#  'F_-1100_angle_201.db',
#  'F_-1100_angle_206.db',
#  'F_-1100_angle_21.db',
#  'F_-1100_angle_211.db',
#  'F_-1100_angle_216.db',
#  'F_-1100_angle_221.db',
#  'F_-1100_angle_226.db',
#  'F_-1100_angle_231.db',
#  'F_-1100_angle_236.db',
#  'F_-1100_angle_241.db',
#  'F_-1100_angle_246.db',
#  'F_-1100_angle_251.db',
#  'F_-1100_angle_256.db',
#  'F_-1100_angle_26.db',
#  'F_-1100_angle_261.db',
#  'F_-1100_angle_266.db',
#  'F_-1100_angle_271.db',
#  'F_-1100_angle_276.db',
#  'F_-1100_angle_281.db',
#  'F_-1100_angle_286.db',
#  'F_-1100_angle_291.db',
#  'F_-1100_angle_296.db',
#  'F_-1100_angle_301.db',
#  'F_-1100_angle_306.db',
#  'F_-1100_angle_31.db',
#  'F_-1100_angle_311.db',
#  'F_-1100_angle_316.db',
#  'F_-1100_angle_321.db',
#  'F_-1100_angle_326.db',
#  'F_-1100_angle_331.db',
#  'F_-1100_angle_336.db',
#  'F_-1100_angle_341.db',
#  'F_-1100_angle_346.db',
#  'F_-1100_angle_351.db',
#  'F_-1100_angle_356.db',
#  'F_-1100_angle_36.db',
#  'F_-1100_angle_41.db',
#  'F_-1100_angle_46.db',
#  'F_-1100_angle_51.db',
#  'F_-1100_angle_56.db',
#  'F_-1100_angle_6.db',
#  'F_-1100_angle_61.db',
#  'F_-1100_angle_66.db',
#  'F_-1100_angle_71.db',
#  'F_-1100_angle_76.db',
#  'F_-1100_angle_81.db',
#  'F_-1100_angle_86.db',
#  'F_-1100_angle_91.db',
#  'F_-1100_angle_96.db',
#  'F_-1150_angle_1.db',
#  'F_-1150_angle_101.db',
#  'F_-1150_angle_106.db',
#  'F_-1150_angle_11.db',
#  'F_-1150_angle_111.db',
#  'F_-1150_angle_116.db',
#  'F_-1150_angle_121.db',
#  'F_-1150_angle_126.db',
#  'F_-1150_angle_131.db',
#  'F_-1150_angle_136.db',
#  'F_-1150_angle_141.db',
#  'F_-1150_angle_146.db',
#  'F_-1150_angle_151.db',
#  'F_-1150_angle_156.db',
#  'F_-1150_angle_16.db',
#  'F_-1150_angle_161.db',
#  'F_-1150_angle_166.db',
#  'F_-1150_angle_171.db',
#  'F_-1150_angle_176.db',
#  'F_-1150_angle_181.db',
#  'F_-1150_angle_186.db',
#  'F_-1150_angle_191.db',
#  'F_-1150_angle_196.db',
#  'F_-1150_angle_201.db',
#  'F_-1150_angle_206.db',
#  'F_-1150_angle_21.db',
#  'F_-1150_angle_211.db',
#  'F_-1150_angle_216.db',
#  'F_-1150_angle_221.db',
#  'F_-1150_angle_226.db',
#  'F_-1150_angle_231.db',
#  'F_-1150_angle_236.db',
#  'F_-1150_angle_241.db',
#  'F_-1150_angle_246.db',
#  'F_-1150_angle_251.db',
#  'F_-1150_angle_256.db',
#  'F_-1150_angle_26.db',
#  'F_-1150_angle_261.db',
#  'F_-1150_angle_266.db',
#  'F_-1150_angle_271.db',
#  'F_-1150_angle_276.db',
#  'F_-1150_angle_281.db',
#  'F_-1150_angle_286.db',
#  'F_-1150_angle_291.db',
#  'F_-1150_angle_296.db',
#  'F_-1150_angle_301.db',
#  'F_-1150_angle_306.db',
#  'F_-1150_angle_31.db',
#  'F_-1150_angle_311.db',
#  'F_-1150_angle_316.db',
#  'F_-1150_angle_321.db',
#  'F_-1150_angle_326.db',
#  'F_-1150_angle_331.db',
#  'F_-1150_angle_336.db',
#  'F_-1150_angle_341.db',
#  'F_-1150_angle_346.db',
#  'F_-1150_angle_351.db',
#  'F_-1150_angle_356.db',
#  'F_-1150_angle_36.db',
#  'F_-1150_angle_41.db',
#  'F_-1150_angle_46.db',
#  'F_-1150_angle_51.db',
#  'F_-1150_angle_56.db',
#  'F_-1150_angle_6.db',
#  'F_-1150_angle_61.db',
#  'F_-1150_angle_66.db',
#  'F_-1150_angle_71.db',
#  'F_-1150_angle_76.db',
#  'F_-1150_angle_81.db',
#  'F_-1150_angle_86.db',
#  'F_-1150_angle_91.db',
#  'F_-1150_angle_96.db',
#  'F_-1200_angle_1.db',
#  'F_-1200_angle_101.db',
#  'F_-1200_angle_106.db',
#  'F_-1200_angle_11.db',
#  'F_-1200_angle_111.db',
#  'F_-1200_angle_116.db',
#  'F_-1200_angle_121.db',
#  'F_-1200_angle_126.db',
#  'F_-1200_angle_131.db',
#  'F_-1200_angle_136.db',
#  'F_-1200_angle_141.db',
#  'F_-1200_angle_146.db',
#  'F_-1200_angle_151.db',
#  'F_-1200_angle_156.db',
#  'F_-1200_angle_16.db',
#  'F_-1200_angle_161.db',
#  'F_-1200_angle_166.db',
#  'F_-1200_angle_171.db',
#  'F_-1200_angle_176.db',
#  'F_-1200_angle_181.db',
#  'F_-1200_angle_186.db',
#  'F_-1200_angle_191.db',
#  'F_-1200_angle_196.db',
#  'F_-1200_angle_201.db',
#  'F_-1200_angle_206.db',
#  'F_-1200_angle_21.db',
#  'F_-1200_angle_211.db',
#  'F_-1200_angle_216.db',
#  'F_-1200_angle_221.db',
#  'F_-1200_angle_226.db',
#  'F_-1200_angle_231.db',
#  'F_-1200_angle_236.db',
#  'F_-1200_angle_241.db',
#  'F_-1200_angle_246.db',
#  'F_-1200_angle_251.db',
#  'F_-1200_angle_256.db',
#  'F_-1200_angle_26.db',
#  'F_-1200_angle_261.db',
#  'F_-1200_angle_266.db',
#  'F_-1200_angle_271.db',
#  'F_-1200_angle_276.db',
#  'F_-1200_angle_281.db',
#  'F_-1200_angle_286.db',
#  'F_-1200_angle_291.db',
#  'F_-1200_angle_296.db',
#  'F_-1200_angle_301.db',
#  'F_-1200_angle_306.db',
#  'F_-1200_angle_31.db',
#  'F_-1200_angle_311.db',
#  'F_-1200_angle_316.db',
#  'F_-1200_angle_321.db',
#  'F_-1200_angle_326.db',
#  'F_-1200_angle_331.db',
#  'F_-1200_angle_336.db',
#  'F_-1200_angle_341.db',
#  'F_-1200_angle_346.db',
#  'F_-1200_angle_351.db',
#  'F_-1200_angle_356.db',
#  'F_-1200_angle_36.db',
#  'F_-1200_angle_41.db',
#  'F_-1200_angle_46.db',
#  'F_-1200_angle_51.db',
#  'F_-1200_angle_56.db',
#  'F_-1200_angle_6.db',
#  'F_-1200_angle_61.db',
#  'F_-1200_angle_66.db',
#  'F_-1200_angle_71.db',
#  'F_-1200_angle_76.db',
#  'F_-1200_angle_81.db',
#  'F_-1200_angle_86.db',
#  'F_-1200_angle_91.db',
#  'F_-1200_angle_96.db',
#  'F_-1250_angle_1.db',
#  'F_-1250_angle_101.db',
#  'F_-1250_angle_106.db',
#  'F_-1250_angle_11.db',
#  'F_-1250_angle_111.db',
#  'F_-1250_angle_116.db',
#  'F_-1250_angle_121.db',
#  'F_-1250_angle_126.db',
#  'F_-1250_angle_131.db',
#  'F_-1250_angle_136.db',
#  'F_-1250_angle_141.db',
#  'F_-1250_angle_146.db',
#  'F_-1250_angle_151.db',
#  'F_-1250_angle_156.db',
#  'F_-1250_angle_16.db',
#  'F_-1250_angle_161.db',
#  'F_-1250_angle_166.db',
#  'F_-1250_angle_171.db',
#  'F_-1250_angle_176.db',
#  'F_-1250_angle_181.db',
#  'F_-1250_angle_186.db',
#  'F_-1250_angle_191.db',
#  'F_-1250_angle_196.db',
#  'F_-1250_angle_201.db',
#  'F_-1250_angle_206.db',
#  'F_-1250_angle_21.db',
#  'F_-1250_angle_211.db',
#  'F_-1250_angle_216.db',
#  'F_-1250_angle_221.db',
#  'F_-1250_angle_226.db',
#  'F_-1250_angle_231.db',
#  'F_-1250_angle_236.db',
#  'F_-1250_angle_241.db',
#  'F_-1250_angle_246.db',
#  'F_-1250_angle_251.db',
#  'F_-1250_angle_256.db',
#  'F_-1250_angle_26.db',
#  'F_-1250_angle_261.db',
#  'F_-1250_angle_266.db',
#  'F_-1250_angle_271.db',
#  'F_-1250_angle_276.db',
#  'F_-1250_angle_281.db',
#  'F_-1250_angle_286.db',
#  'F_-1250_angle_291.db',
#  'F_-1250_angle_296.db',
#  'F_-1250_angle_301.db',
#  'F_-1250_angle_306.db',
#  'F_-1250_angle_31.db',
#  'F_-1250_angle_311.db',
#  'F_-1250_angle_316.db',
#  'F_-1250_angle_321.db',
#  'F_-1250_angle_326.db',
#  'F_-1250_angle_331.db',
#  'F_-1250_angle_336.db',
#  'F_-1250_angle_341.db',
#  'F_-1250_angle_346.db',
#  'F_-1250_angle_351.db',
#  'F_-1250_angle_356.db',
#  'F_-1250_angle_36.db',
#  'F_-1250_angle_41.db',
#  'F_-1250_angle_46.db',
#  'F_-1250_angle_51.db',
#  'F_-1250_angle_56.db',
#  'F_-1250_angle_6.db',
#  'F_-1250_angle_61.db',
#  'F_-1250_angle_66.db',
#  'F_-1250_angle_71.db',
#  'F_-1250_angle_76.db',
#  'F_-1250_angle_81.db',
#  'F_-1250_angle_86.db',
#  'F_-1250_angle_91.db',
#  'F_-1250_angle_96.db',
#  'F_-1300_angle_1.db',
#  'F_-1300_angle_101.db',
#  'F_-1300_angle_106.db',
#  'F_-1300_angle_11.db',
#  'F_-1300_angle_111.db',
#  'F_-1300_angle_116.db',
#  'F_-1300_angle_121.db',
#  'F_-1300_angle_126.db',
#  'F_-1300_angle_131.db',
#  'F_-1300_angle_136.db',
#  'F_-1300_angle_141.db',
#  'F_-1300_angle_146.db',
#  'F_-1300_angle_151.db',
#  'F_-1300_angle_156.db',
#  'F_-1300_angle_16.db',
#  'F_-1300_angle_161.db',
#  'F_-1300_angle_166.db',
#  'F_-1300_angle_171.db',
#  'F_-1300_angle_176.db',
#  'F_-1300_angle_181.db',
#  'F_-1300_angle_186.db',
#  'F_-1300_angle_191.db',
#  'F_-1300_angle_196.db',
#  'F_-1300_angle_201.db',
#  'F_-1300_angle_206.db',
#  'F_-1300_angle_21.db',
#  'F_-1300_angle_211.db',
#  'F_-1300_angle_216.db',
#  'F_-1300_angle_221.db',
#  'F_-1300_angle_226.db',
#  'F_-1300_angle_231.db',
#  'F_-1300_angle_236.db',
#  'F_-1300_angle_241.db',
#  'F_-1300_angle_246.db',
#  'F_-1300_angle_251.db',
#  'F_-1300_angle_256.db',
#  'F_-1300_angle_26.db',
#  'F_-1300_angle_261.db',
#  'F_-1300_angle_266.db',
#  'F_-1300_angle_271.db',
#  'F_-1300_angle_276.db',
#  'F_-1300_angle_281.db',
#  'F_-1300_angle_286.db',
#  'F_-1300_angle_291.db',
#  'F_-1300_angle_296.db',
#  'F_-1300_angle_301.db',
#  'F_-1300_angle_306.db',
#  'F_-1300_angle_31.db',
#  'F_-1300_angle_311.db',
#  'F_-1300_angle_316.db',
#  'F_-1300_angle_321.db',
#  'F_-1300_angle_326.db',
#  'F_-1300_angle_331.db',
#  'F_-1300_angle_336.db',
#  'F_-1300_angle_341.db',
#  'F_-1300_angle_346.db',
#  'F_-1300_angle_351.db',
#  'F_-1300_angle_356.db',
#  'F_-1300_angle_36.db',
#  'F_-1300_angle_41.db',
#  'F_-1300_angle_46.db',
#  'F_-1300_angle_51.db',
#  'F_-1300_angle_56.db',
#  'F_-1300_angle_6.db',
#  'F_-1300_angle_61.db',
#  'F_-1300_angle_66.db',
#  'F_-1300_angle_71.db',
#  'F_-1300_angle_76.db',
#  'F_-1300_angle_81.db',
#  'F_-1300_angle_86.db',
#  'F_-1300_angle_91.db',
#  'F_-1300_angle_96.db',
#  'F_-1350_angle_1.db',
#  'F_-1350_angle_101.db',
#  'F_-1350_angle_106.db',
#  'F_-1350_angle_11.db',
#  'F_-1350_angle_111.db',
#  'F_-1350_angle_116.db',
#  'F_-1350_angle_121.db',
#  'F_-1350_angle_126.db',
#  'F_-1350_angle_131.db',
#  'F_-1350_angle_136.db',
#  'F_-1350_angle_141.db',
#  'F_-1350_angle_146.db',
#  'F_-1350_angle_151.db',
#  'F_-1350_angle_156.db',
#  'F_-1350_angle_16.db',
#  'F_-1350_angle_161.db',
#  'F_-1350_angle_166.db',
#  'F_-1350_angle_171.db',
#  'F_-1350_angle_176.db',
#  'F_-1350_angle_181.db',
#  'F_-1350_angle_186.db',
#  'F_-1350_angle_191.db',
#  'F_-1350_angle_196.db',
#  'F_-1350_angle_201.db',
#  'F_-1350_angle_206.db',
#  'F_-1350_angle_21.db',
#  'F_-1350_angle_211.db',
#  'F_-1350_angle_216.db',
#  'F_-1350_angle_221.db',
#  'F_-1350_angle_226.db',
#  'F_-1350_angle_231.db',
#  'F_-1350_angle_236.db',
#  'F_-1350_angle_241.db',
#  'F_-1350_angle_246.db',
#  'F_-1350_angle_251.db',
#  'F_-1350_angle_256.db',
#  'F_-1350_angle_26.db',
#  'F_-1350_angle_261.db',
#  'F_-1350_angle_266.db',
#  'F_-1350_angle_271.db',
#  'F_-1350_angle_276.db',
#  'F_-1350_angle_281.db',
#  'F_-1350_angle_286.db',
#  'F_-1350_angle_291.db',
#  'F_-1350_angle_296.db',
#  'F_-1350_angle_301.db',
#  'F_-1350_angle_306.db',
#  'F_-1350_angle_31.db',
#  'F_-1350_angle_311.db',
#  'F_-1350_angle_316.db',
#  'F_-1350_angle_321.db',
#  'F_-1350_angle_326.db',
#  'F_-1350_angle_331.db',
#  'F_-1350_angle_336.db',
#  'F_-1350_angle_341.db',
#  'F_-1350_angle_346.db',
#  'F_-1350_angle_351.db',
#  'F_-1350_angle_356.db',
#  'F_-1350_angle_36.db',
#  'F_-1350_angle_41.db',
#  'F_-1350_angle_46.db',
#  'F_-1350_angle_51.db',
#  'F_-1350_angle_56.db',
#  'F_-1350_angle_6.db',
#  'F_-1350_angle_61.db',
#  'F_-1350_angle_66.db',
#  'F_-1350_angle_71.db',
#  'F_-1350_angle_76.db',
#  'F_-1350_angle_81.db',
#  'F_-1350_angle_86.db',
#  'F_-1350_angle_91.db',
#  'F_-1350_angle_96.db',
#  'F_-1400_angle_1.db',
#  'F_-1400_angle_101.db',
#  'F_-1400_angle_106.db',
#  'F_-1400_angle_11.db',
#  'F_-1400_angle_111.db',
#  'F_-1400_angle_116.db',
#  'F_-1400_angle_121.db',
#  'F_-1400_angle_126.db',
#  'F_-1400_angle_131.db',
#  'F_-1400_angle_136.db',
#  'F_-1400_angle_141.db',
#  'F_-1400_angle_146.db',
#  'F_-1400_angle_151.db',
#  'F_-1400_angle_156.db',
#  'F_-1400_angle_16.db',
#  'F_-1400_angle_161.db',
#  'F_-1400_angle_166.db',
#  'F_-1400_angle_171.db',
#  'F_-1400_angle_176.db',
#  'F_-1400_angle_181.db',
#  'F_-1400_angle_186.db',
#  'F_-1400_angle_191.db',
#  'F_-1400_angle_196.db',
#  'F_-1400_angle_201.db',
#  'F_-1400_angle_206.db',
#  'F_-1400_angle_21.db',
#  'F_-1400_angle_211.db',
#  'F_-1400_angle_216.db',
#  'F_-1400_angle_221.db',
#  'F_-1400_angle_226.db',
#  'F_-1400_angle_231.db',
#  'F_-1400_angle_236.db',
#  'F_-1400_angle_241.db',
#  'F_-1400_angle_246.db',
#  'F_-1400_angle_251.db',
#  'F_-1400_angle_256.db',
#  'F_-1400_angle_26.db',
#  'F_-1400_angle_261.db',
#  'F_-1400_angle_266.db',
#  'F_-1400_angle_271.db',
#  'F_-1400_angle_276.db',
#  'F_-1400_angle_281.db',
#  'F_-1400_angle_286.db',
#  'F_-1400_angle_291.db',
#  'F_-1400_angle_296.db',
#  'F_-1400_angle_301.db',
#  'F_-1400_angle_306.db',
#  'F_-1400_angle_31.db',
#  'F_-1400_angle_311.db',
#  'F_-1400_angle_316.db',
#  'F_-1400_angle_321.db',
#  'F_-1400_angle_326.db',
#  'F_-1400_angle_331.db',
#  'F_-1400_angle_336.db',
#  'F_-1400_angle_341.db',
#  'F_-1400_angle_346.db',
#  'F_-1400_angle_351.db',
#  'F_-1400_angle_356.db',
#  'F_-1400_angle_36.db',
#  'F_-1400_angle_41.db',
#  'F_-1400_angle_46.db',
#  'F_-1400_angle_51.db',
#  'F_-1400_angle_56.db',
#  'F_-1400_angle_6.db',
#  'F_-1400_angle_61.db',
#  'F_-1400_angle_66.db',
#  'F_-1400_angle_71.db',
#  'F_-1400_angle_76.db',
#  'F_-1400_angle_81.db',
#  'F_-1400_angle_86.db',
#  'F_-1400_angle_91.db',
#  'F_-1400_angle_96.db',
#  'F_-1450_angle_1.db',
#  'F_-1450_angle_101.db',
#  'F_-1450_angle_106.db',
#  'F_-1450_angle_11.db',
#  'F_-1450_angle_111.db',
#  'F_-1450_angle_116.db',
#  'F_-1450_angle_121.db',
#  'F_-1450_angle_126.db',
#  'F_-1450_angle_131.db',
#  'F_-1450_angle_136.db',
#  'F_-1450_angle_141.db',
#  'F_-1450_angle_146.db',
#  'F_-1450_angle_151.db',
#  'F_-1450_angle_156.db',
#  'F_-1450_angle_16.db',
#  'F_-1450_angle_161.db',
#  'F_-1450_angle_166.db',
#  'F_-1450_angle_171.db',
#  'F_-1450_angle_176.db',
#  'F_-1450_angle_181.db',
#  'F_-1450_angle_186.db',
#  'F_-1450_angle_191.db',
#  'F_-1450_angle_196.db',
#  'F_-1450_angle_201.db',
#  'F_-1450_angle_206.db',
#  'F_-1450_angle_21.db',
#  'F_-1450_angle_211.db',
#  'F_-1450_angle_216.db',
#  'F_-1450_angle_221.db',
#  'F_-1450_angle_226.db',
#  'F_-1450_angle_231.db',
#  'F_-1450_angle_236.db',
#  'F_-1450_angle_241.db',
#  'F_-1450_angle_246.db',
#  'F_-1450_angle_251.db',
#  'F_-1450_angle_256.db',
#  'F_-1450_angle_26.db',
#  'F_-1450_angle_261.db',
#  'F_-1450_angle_266.db',
#  'F_-1450_angle_271.db',
#  'F_-1450_angle_276.db',
#  'F_-1450_angle_281.db',
#  'F_-1450_angle_286.db',
#  'F_-1450_angle_291.db',
#  'F_-1450_angle_296.db',
#  'F_-1450_angle_301.db',
#  'F_-1450_angle_306.db',
#  'F_-1450_angle_31.db',
#  'F_-1450_angle_311.db',
#  'F_-1450_angle_316.db',
#  'F_-1450_angle_321.db',
#  'F_-1450_angle_326.db',
#  'F_-1450_angle_331.db',
#  'F_-1450_angle_336.db',
#  'F_-1450_angle_341.db',
#  'F_-1450_angle_346.db',
#  'F_-1450_angle_351.db',
#  'F_-1450_angle_356.db',
#  'F_-1450_angle_36.db',
#  'F_-1450_angle_41.db',
#  'F_-1450_angle_46.db',
#  'F_-1450_angle_51.db',
#  'F_-1450_angle_56.db',
#  'F_-1450_angle_6.db',
#  'F_-1450_angle_61.db',
#  'F_-1450_angle_66.db',
#  'F_-1450_angle_71.db',
#  'F_-1450_angle_76.db',
#  'F_-1450_angle_81.db',
#  'F_-1450_angle_86.db',
#  'F_-1450_angle_91.db',
#  'F_-1450_angle_96.db',
#  'F_-1500_angle_1.db',
#  'F_-1500_angle_101.db',
#  'F_-1500_angle_106.db',
#  'F_-1500_angle_11.db',
#  'F_-1500_angle_111.db',
#  'F_-1500_angle_116.db',
#  'F_-1500_angle_121.db',
#  'F_-1500_angle_126.db',
#  'F_-1500_angle_131.db',
#  'F_-1500_angle_136.db',
#  'F_-1500_angle_141.db',
#  'F_-1500_angle_146.db',
#  'F_-1500_angle_151.db',
#  'F_-1500_angle_156.db',
#  'F_-1500_angle_16.db',
#  'F_-1500_angle_161.db',
#  'F_-1500_angle_166.db',
#  'F_-1500_angle_171.db',
#  'F_-1500_angle_176.db',
#  'F_-1500_angle_181.db',
#  'F_-1500_angle_186.db',
#  'F_-1500_angle_191.db',
#  'F_-1500_angle_196.db',
#  'F_-1500_angle_201.db',
#  'F_-1500_angle_206.db',
#  'F_-1500_angle_21.db',
#  'F_-1500_angle_211.db',
#  'F_-1500_angle_216.db',
#  'F_-1500_angle_221.db',
#  'F_-1500_angle_226.db',
#  'F_-1500_angle_231.db',
#  'F_-1500_angle_236.db',
#  'F_-1500_angle_241.db',
#  'F_-1500_angle_246.db',
#  'F_-1500_angle_251.db',
#  'F_-1500_angle_256.db',
#  'F_-1500_angle_26.db',
#  'F_-1500_angle_261.db',
#  'F_-1500_angle_266.db',
#  'F_-1500_angle_271.db',
#  'F_-1500_angle_276.db',
#  'F_-1500_angle_281.db',
#  'F_-1500_angle_286.db',
#  'F_-1500_angle_291.db',
#  'F_-1500_angle_296.db',
#  'F_-1500_angle_301.db',
#  'F_-1500_angle_306.db',
#  'F_-1500_angle_31.db',
#  'F_-1500_angle_311.db',
#  'F_-1500_angle_316.db',
#  'F_-1500_angle_321.db',
#  'F_-1500_angle_326.db',
#  'F_-1500_angle_331.db',
#  'F_-1500_angle_336.db',
#  'F_-1500_angle_341.db',
#  'F_-1500_angle_346.db',
#  'F_-1500_angle_351.db',
#  'F_-1500_angle_356.db',
#  'F_-1500_angle_36.db',
#  'F_-1500_angle_41.db',
#  'F_-1500_angle_46.db',
#  'F_-1500_angle_51.db',
#  'F_-1500_angle_56.db',
#  'F_-1500_angle_6.db',
#  'F_-1500_angle_61.db',
#  'F_-1500_angle_66.db',
#  'F_-1500_angle_71.db',
#  'F_-1500_angle_76.db',
#  'F_-1500_angle_81.db',
#  'F_-1500_angle_86.db',
#  'F_-1500_angle_91.db',
#  'F_-1500_angle_96.db',
#  'F_-150_angle_1.db',
#  'F_-150_angle_101.db',
#  'F_-150_angle_106.db',
#  'F_-150_angle_11.db',
#  'F_-150_angle_111.db',
#  'F_-150_angle_116.db',
#  'F_-150_angle_121.db',
#  'F_-150_angle_126.db',
#  'F_-150_angle_131.db',
#  'F_-150_angle_136.db',
#  'F_-150_angle_141.db',
#  'F_-150_angle_146.db',
#  'F_-150_angle_151.db',
#  'F_-150_angle_156.db',
#  'F_-150_angle_16.db',
#  'F_-150_angle_161.db',
#  'F_-150_angle_166.db',
#  'F_-150_angle_171.db',
#  'F_-150_angle_176.db',
#  'F_-150_angle_181.db',
#  'F_-150_angle_186.db',
#  'F_-150_angle_191.db',
#  'F_-150_angle_196.db',
#  'F_-150_angle_201.db',
#  'F_-150_angle_206.db',
#  'F_-150_angle_21.db',
#  'F_-150_angle_211.db',
#  'F_-150_angle_216.db',
#  'F_-150_angle_221.db',
#  'F_-150_angle_226.db',
#  'F_-150_angle_231.db',
#  'F_-150_angle_236.db',
#  'F_-150_angle_241.db',
#  'F_-150_angle_246.db',
#  'F_-150_angle_251.db',
#  'F_-150_angle_256.db',
#  'F_-150_angle_26.db',
#  'F_-150_angle_261.db',
#  'F_-150_angle_266.db',
#  'F_-150_angle_271.db',
#  'F_-150_angle_276.db',
#  'F_-150_angle_281.db',
#  'F_-150_angle_286.db',
#  'F_-150_angle_291.db',
#  'F_-150_angle_296.db',
#  'F_-150_angle_301.db',
#  'F_-150_angle_306.db',
#  'F_-150_angle_31.db',
#  'F_-150_angle_311.db',
#  'F_-150_angle_316.db',
#  'F_-150_angle_321.db',
#  'F_-150_angle_326.db',
#  'F_-150_angle_331.db',
#  'F_-150_angle_336.db',
#  'F_-150_angle_341.db',
#  'F_-150_angle_346.db',
#  'F_-150_angle_351.db',
#  'F_-150_angle_356.db',
#  'F_-150_angle_36.db',
#  'F_-150_angle_41.db',
#  'F_-150_angle_46.db',
#  'F_-150_angle_51.db',
#  'F_-150_angle_56.db',
#  'F_-150_angle_6.db',
#  'F_-150_angle_61.db',
#  'F_-150_angle_66.db',
#  'F_-150_angle_71.db',
#  'F_-150_angle_76.db',
#  'F_-150_angle_81.db',
#  'F_-150_angle_86.db',
#  'F_-150_angle_91.db',
#  'F_-150_angle_96.db',
#  'F_-1550_angle_1.db',
#  'F_-1550_angle_101.db',
#  'F_-1550_angle_106.db',
#  'F_-1550_angle_11.db',
#  'F_-1550_angle_111.db',
#  'F_-1550_angle_116.db',
#  'F_-1550_angle_121.db',
#  'F_-1550_angle_126.db',
#  'F_-1550_angle_131.db',
#  'F_-1550_angle_136.db',
#  'F_-1550_angle_141.db',
#  'F_-1550_angle_146.db',
#  'F_-1550_angle_151.db',
#  'F_-1550_angle_156.db',
#  'F_-1550_angle_16.db',
#  'F_-1550_angle_161.db',
#  'F_-1550_angle_166.db',
#  'F_-1550_angle_171.db',
#  'F_-1550_angle_176.db',
#  'F_-1550_angle_181.db',
#  'F_-1550_angle_186.db',
#  'F_-1550_angle_191.db',
#  'F_-1550_angle_196.db',
#  'F_-1550_angle_201.db',
#  'F_-1550_angle_206.db',
#  'F_-1550_angle_21.db',
#  'F_-1550_angle_211.db',
#  'F_-1550_angle_216.db',
#  'F_-1550_angle_221.db',
#  'F_-1550_angle_226.db',
#  'F_-1550_angle_231.db',
#  'F_-1550_angle_236.db',
#  'F_-1550_angle_241.db',
#  'F_-1550_angle_246.db',
#  'F_-1550_angle_251.db',
#  'F_-1550_angle_256.db',
#  'F_-1550_angle_26.db',
#  'F_-1550_angle_261.db',
#  'F_-1550_angle_266.db',
#  'F_-1550_angle_271.db',
#  'F_-1550_angle_276.db',
#  'F_-1550_angle_281.db',
#  'F_-1550_angle_286.db',
#  'F_-1550_angle_291.db',
#  'F_-1550_angle_296.db',
#  'F_-1550_angle_301.db',
#  'F_-1550_angle_306.db',
#  'F_-1550_angle_31.db',
#  'F_-1550_angle_311.db',
#  'F_-1550_angle_316.db',
#  'F_-1550_angle_321.db',
#  'F_-1550_angle_326.db',
#  'F_-1550_angle_331.db',
#  'F_-1550_angle_336.db',
#  'F_-1550_angle_341.db',
#  'F_-1550_angle_346.db',
#  'F_-1550_angle_351.db',
#  'F_-1550_angle_356.db',
#  'F_-1550_angle_36.db',
#  'F_-1550_angle_41.db',
#  'F_-1550_angle_46.db',
#  'F_-1550_angle_51.db',
#  'F_-1550_angle_56.db',
#  'F_-1550_angle_6.db',
#  ...]
